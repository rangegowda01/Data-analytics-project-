# %% [markdown]
# ## Project Title : Amazon Kitchenware Dataset Analysis Project 1
#
# ## Purpose
#
# Analyzing the Amazon Kitchenware Dataset with Python libraries like pandas and matplotlib enables businesses to extract valuable insights for informed decision-making. It helps in understanding customer preferences, identifying market trends, analyzing seasonal patterns, assessing customer sentiment, understanding pricing dynamics, facilitating inventory management, developing recommendation systems, and conducting competitor analysis. Overall, leveraging this dataset empowers businesses in the kitchenware industry to optimize their product offerings, marketing strategies, and operational efficiency to meet customer needs and maximize performance.

# %% [markdown]
# ## Step 1 : Installing the Packages beforehand

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Requirement already satisfied: pandas in c:\users\user\anaconda3\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.23.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\user\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\user\anaconda3\lib\site-packages (3.8.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy<2,>=1.21 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\anaconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\user\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
# Importing the necessary packages for data manipulation and visualisation

import pandas as pd  # data manipulation
import matplotlib.pyplot as plt # data visualization

# %% [markdown]
# ## Step 2 : Loading the files from the local system to the Notebook

# %%
# Load the files

data = pd.read_csv('C:/Project/amazon_kitchenware.csv')  # To read the csv file from the file path 
print(data)
# Out:
#                                                  title                 brand  \
# 0    Amazon Basics Digital Kitchen Scale with LCD D...         Amazon Basics
# 1    Vegetable Chopper, Pro Onion Chopper, 14 in 1M...              SNIFITAR
# 2    Hefty Ultra Strong Tall Kitchen Trash Bags, La...                 Hefty
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...         Amazon Basics
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...              Etekcity
# ..                                                 ...                   ...
# 257  Amazon Basics Flextra Tall Kitchen Drawstring ...         Amazon Basics
# 258  16oz Oil Dispenser Bottle for Kitchen - 2 in 1...            TrendPlain
# 259  Non-slip Pastry Mat Extra Large with Measureme...  Folksy Super Kitchen
# 260  Lifewit 5 Pack Drawer Dividers Plastic 4" High...               Lifewit
# 261  Large Food Storage Containers with Lids Airtig...            PANTRYSTAR
#
#                                            description  stars  reviewsCount  \
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 1                                                  NaN    4.2          7188
# 2    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# ..                                                 ...    ...           ...
# 257  Product DescriptionAmazon Basics Flextra Tall ...    4.5         15590
# 258                                                NaN    4.3           247
# 259                                                NaN    4.8         21936
# 260                                                NaN    4.6           698
# 261                                                NaN    4.6         11245
#
#     price/currency  price/value  \
# 0                $        12.59
# 1                $        17.99
# 2                $        10.18
# 3                $        13.94
# 4                $        13.99
# ..             ...          ...
# 257              $        12.72
# 258              $        12.99
# 259              $        15.96
# 260              $        19.99
# 261              $        17.99
#
#                                            breadCrumbs        asin  \
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 1    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0B41NL1JC
# 2    Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# ..                                                 ...         ...
# 257  Health & Household › Household Supplies › Pape...  B092VQMW7T
# 258  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0CJF94M8J
# 259  Home & Kitchen › Kitchen & Dining › Bakeware ›...  B01ACUA8HC
# 260  Home & Kitchen › Storage & Organization › Clot...  B0C4L9MTB7
# 261  Home & Kitchen › Kitchen & Dining › Storage & ...  B08DHCDJHK
#
#                                       url
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 1    https://www.amazon.com/dp/B0B41NL1JC
# 2    https://www.amazon.com/dp/B01BZ0LXL8
# 3    https://www.amazon.com/dp/B093X8QQ12
# 4    https://www.amazon.com/dp/B0113UZJE2
# ..                                    ...
# 257  https://www.amazon.com/dp/B092VQMW7T
# 258  https://www.amazon.com/dp/B0CJF94M8J
# 259  https://www.amazon.com/dp/B01ACUA8HC
# 260  https://www.amazon.com/dp/B0C4L9MTB7
# 261  https://www.amazon.com/dp/B08DHCDJHK
#
# [262 rows x 10 columns]

# %% [markdown]
# ## Step 3 : Data view

# %%
# print the first 5 rows of the dataset
data.head()
# Out:
#                                                title          brand  \
# 0  Amazon Basics Digital Kitchen Scale with LCD D...  Amazon Basics
# 1  Vegetable Chopper, Pro Onion Chopper, 14 in 1M...       SNIFITAR
# 2  Hefty Ultra Strong Tall Kitchen Trash Bags, La...          Hefty
# 3  Amazon Basics Tall Kitchen Drawstring Trash Ba...  Amazon Basics
# 4  Etekcity Food Scale, Digital Kitchen Scale, 30...       Etekcity
#
#                                          description  stars  reviewsCount  \
# 0  Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 1                                                NaN    4.2          7188
# 2  Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3  Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4  This Etekcity digital scale has endless uses f...    4.6        166658
#
#   price/currency  price/value  \
# 0              $        12.59
# 1              $        17.99
# 2              $        10.18
# 3              $        13.94
# 4              $        13.99
#
#                                          breadCrumbs        asin  \
# 0  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 1  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0B41NL1JC
# 2  Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3  Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
#
#                                     url
# 0  https://www.amazon.com/dp/B06X9NQ8GX
# 1  https://www.amazon.com/dp/B0B41NL1JC
# 2  https://www.amazon.com/dp/B01BZ0LXL8
# 3  https://www.amazon.com/dp/B093X8QQ12
# 4  https://www.amazon.com/dp/B0113UZJE2

# %%
# To print the column names present in the dataset
data.columns
# Out:
# Index(['title', 'brand', 'description', 'stars', 'reviewsCount',
#        'price/currency', 'price/value', 'breadCrumbs', 'asin', 'url'],
#       dtype='object')

# %%
# Display the summary information about Dataframe
data.info
# Out:
# <bound method DataFrame.info of                                                  title                 brand  \
# 0    Amazon Basics Digital Kitchen Scale with LCD D...         Amazon Basics
# 1    Vegetable Chopper, Pro Onion Chopper, 14 in 1M...              SNIFITAR
# 2    Hefty Ultra Strong Tall Kitchen Trash Bags, La...                 Hefty
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...         Amazon Basics
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...              Etekcity
# ..                                                 ...                   ...
# 257  Amazon Basics Flextra Tall Kitchen Drawstring ...         Amazon Basics
# 258  16oz Oil Dispenser Bottle for Kitchen - 2 in 1...            TrendPlain
# 259  Non-slip Pastry Mat Extra Large with Measureme...  Folksy Super Kitchen
# 260  Lifewit 5 Pack Drawer Dividers Plastic 4" High...               Lifewit
# 261  Large Food Storage Containers with Lids Airtig...            PANTRYSTAR
#
#                                            description  stars  reviewsCount  \
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 1                                                  NaN    4.2          7188
# 2    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# ..                                                 ...    ...           ...
# 257  Product DescriptionAmazon Basics Flextra Tall ...    4.5         15590
# 258                                                NaN    4.3           247
# 259                                                NaN    4.8         21936
# 260                                                NaN    4.6           698
# 261                                                NaN    4.6         11245
#
#     price/currency  price/value  \
# 0                $        12.59
# 1                $        17.99
# 2                $        10.18
# 3                $        13.94
# 4                $        13.99
# ..             ...          ...
# 257              $        12.72
# 258              $        12.99
# 259              $        15.96
# 260              $        19.99
# 261              $        17.99
#
#                                            breadCrumbs        asin  \
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 1    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0B41NL1JC
# 2    Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# ..                                                 ...         ...
# 257  Health & Household › Household Supplies › Pape...  B092VQMW7T
# 258  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0CJF94M8J
# 259  Home & Kitchen › Kitchen & Dining › Bakeware ›...  B01ACUA8HC
# 260  Home & Kitchen › Storage & Organization › Clot...  B0C4L9MTB7
# 261  Home & Kitchen › Kitchen & Dining › Storage & ...  B08DHCDJHK
#
#                                       url
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 1    https://www.amazon.com/dp/B0B41NL1JC
# 2    https://www.amazon.com/dp/B01BZ0LXL8
# 3    https://www.amazon.com/dp/B093X8QQ12
# 4    https://www.amazon.com/dp/B0113UZJE2
# ..                                    ...
# 257  https://www.amazon.com/dp/B092VQMW7T
# 258  https://www.amazon.com/dp/B0CJF94M8J
# 259  https://www.amazon.com/dp/B01ACUA8HC
# 260  https://www.amazon.com/dp/B0C4L9MTB7
# 261  https://www.amazon.com/dp/B08DHCDJHK
#
# [262 rows x 10 columns]>

# %%
# Print the shape of the dataset
data.shape
# Out:
# (262, 10)

# %%
# To display the data types of each column in a DataFrame
data.dtypes
# Out:
# title              object
# brand              object
# description        object
# stars             float64
# reviewsCount        int64
# price/currency     object
# price/value       float64
# breadCrumbs        object
# asin               object
# url                object
# dtype: object

# %%
# Display the summary statistics for numerical columns in a DataFrame
data.describe
# Out:
# <bound method NDFrame.describe of                                                  title                 brand  \
# 0    Amazon Basics Digital Kitchen Scale with LCD D...         Amazon Basics
# 1    Vegetable Chopper, Pro Onion Chopper, 14 in 1M...              SNIFITAR
# 2    Hefty Ultra Strong Tall Kitchen Trash Bags, La...                 Hefty
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...         Amazon Basics
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...              Etekcity
# ..                                                 ...                   ...
# 257  Amazon Basics Flextra Tall Kitchen Drawstring ...         Amazon Basics
# 258  16oz Oil Dispenser Bottle for Kitchen - 2 in 1...            TrendPlain
# 259  Non-slip Pastry Mat Extra Large with Measureme...  Folksy Super Kitchen
# 260  Lifewit 5 Pack Drawer Dividers Plastic 4" High...               Lifewit
# 261  Large Food Storage Containers with Lids Airtig...            PANTRYSTAR
#
#                                            description  stars  reviewsCount  \
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 1                                                  NaN    4.2          7188
# 2    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# ..                                                 ...    ...           ...
# 257  Product DescriptionAmazon Basics Flextra Tall ...    4.5         15590
# 258                                                NaN    4.3           247
# 259                                                NaN    4.8         21936
# 260                                                NaN    4.6           698
# 261                                                NaN    4.6         11245
#
#     price/currency  price/value  \
# 0                $        12.59
# 1                $        17.99
# 2                $        10.18
# 3                $        13.94
# 4                $        13.99
# ..             ...          ...
# 257              $        12.72
# 258              $        12.99
# 259              $        15.96
# 260              $        19.99
# 261              $        17.99
#
#                                            breadCrumbs        asin  \
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 1    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0B41NL1JC
# 2    Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# ..                                                 ...         ...
# 257  Health & Household › Household Supplies › Pape...  B092VQMW7T
# 258  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0CJF94M8J
# 259  Home & Kitchen › Kitchen & Dining › Bakeware ›...  B01ACUA8HC
# 260  Home & Kitchen › Storage & Organization › Clot...  B0C4L9MTB7
# 261  Home & Kitchen › Kitchen & Dining › Storage & ...  B08DHCDJHK
#
#                                       url
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 1    https://www.amazon.com/dp/B0B41NL1JC
# 2    https://www.amazon.com/dp/B01BZ0LXL8
# 3    https://www.amazon.com/dp/B093X8QQ12
# 4    https://www.amazon.com/dp/B0113UZJE2
# ..                                    ...
# 257  https://www.amazon.com/dp/B092VQMW7T
# 258  https://www.amazon.com/dp/B0CJF94M8J
# 259  https://www.amazon.com/dp/B01ACUA8HC
# 260  https://www.amazon.com/dp/B0C4L9MTB7
# 261  https://www.amazon.com/dp/B08DHCDJHK
#
# [262 rows x 10 columns]>

# %% [markdown]
# ## Step 4 : Data cleaning / Filteration / Manipulation

# %%
# Display the number of rows in a particular column
data.count()
# Out:
# title             262
# brand             262
# description        82
# stars             262
# reviewsCount      262
# price/currency    259
# price/value       259
# breadCrumbs       261
# asin              262
# url               262
# dtype: int64

# %%
# To get the count of unique values in each column of a DataFrame
data.value_counts
# Out:
# <bound method DataFrame.value_counts of                                                  title                 brand  \
# 0    Amazon Basics Digital Kitchen Scale with LCD D...         Amazon Basics
# 1    Vegetable Chopper, Pro Onion Chopper, 14 in 1M...              SNIFITAR
# 2    Hefty Ultra Strong Tall Kitchen Trash Bags, La...                 Hefty
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...         Amazon Basics
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...              Etekcity
# ..                                                 ...                   ...
# 257  Amazon Basics Flextra Tall Kitchen Drawstring ...         Amazon Basics
# 258  16oz Oil Dispenser Bottle for Kitchen - 2 in 1...            TrendPlain
# 259  Non-slip Pastry Mat Extra Large with Measureme...  Folksy Super Kitchen
# 260  Lifewit 5 Pack Drawer Dividers Plastic 4" High...               Lifewit
# 261  Large Food Storage Containers with Lids Airtig...            PANTRYSTAR
#
#                                            description  stars  reviewsCount  \
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 1                                                  NaN    4.2          7188
# 2    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# ..                                                 ...    ...           ...
# 257  Product DescriptionAmazon Basics Flextra Tall ...    4.5         15590
# 258                                                NaN    4.3           247
# 259                                                NaN    4.8         21936
# 260                                                NaN    4.6           698
# 261                                                NaN    4.6         11245
#
#     price/currency  price/value  \
# 0                $        12.59
# 1                $        17.99
# 2                $        10.18
# 3                $        13.94
# 4                $        13.99
# ..             ...          ...
# 257              $        12.72
# 258              $        12.99
# 259              $        15.96
# 260              $        19.99
# 261              $        17.99
#
#                                            breadCrumbs        asin  \
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 1    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0B41NL1JC
# 2    Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# ..                                                 ...         ...
# 257  Health & Household › Household Supplies › Pape...  B092VQMW7T
# 258  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0CJF94M8J
# 259  Home & Kitchen › Kitchen & Dining › Bakeware ›...  B01ACUA8HC
# 260  Home & Kitchen › Storage & Organization › Clot...  B0C4L9MTB7
# 261  Home & Kitchen › Kitchen & Dining › Storage & ...  B08DHCDJHK
#
#                                       url
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 1    https://www.amazon.com/dp/B0B41NL1JC
# 2    https://www.amazon.com/dp/B01BZ0LXL8
# 3    https://www.amazon.com/dp/B093X8QQ12
# 4    https://www.amazon.com/dp/B0113UZJE2
# ..                                    ...
# 257  https://www.amazon.com/dp/B092VQMW7T
# 258  https://www.amazon.com/dp/B0CJF94M8J
# 259  https://www.amazon.com/dp/B01ACUA8HC
# 260  https://www.amazon.com/dp/B0C4L9MTB7
# 261  https://www.amazon.com/dp/B08DHCDJHK
#
# [262 rows x 10 columns]>

# %%
# It containing all unique values in the 'brand' column of the DataFrame
data['brand'].unique()
# Out:
# array(['Amazon Basics', 'SNIFITAR', 'Hefty', 'Etekcity', 'Mueller',
#        'Zulay Kitchen', 'Scotch-Brite', 'Kitchen Gizmo', 'GGQ', 'Kitsure',
#        'T-fal', 'AGFOO', 'PAKITNER', 'LITTLE COOK SINCE 1995',
#        'Weigh Gram', 'Cisily', 'Animal-Gifts', 'TILUCK', 'KitchenClouds',
#        'Holikme', 'Yonanas', 'AWLKIM', 'Elite Gourmet', 'Sevenblue',
#        'Pyrex', 'Ninja', 'DclobTop', 'Amazer', 'PRAKI', 'ClearSpace',
#        'Lifewit', 'KongNai', 'ROUUO', 'RUBY HORSEPOWER', 'Hiyniaz',
#        'KITEXPERT', 'CAROTE', 'Geedel', 'Koxuky', 'Kitchen Mama',
#        'BLACK+DECKER', 'OTOTO', 'Tovolo', 'Glad', 'Reynolds', 'Seropy',
#        'Victoria', 'JoyJolt', 'PGYARD', 'Storeganize', 'Deiss',
#        'Bonsenkitchen', 'KITCHELLENCE', 'Scrub Daddy', 'HIWARE',
#        'Spring Chef', 'Mueller Austria', 'Cuisinart', 'Joseph Joseph',
#        'HappyTrends', 'KSENDALO', 'FOSJGO', 'Zeppoli', 'SecuCaptain',
#        'Bumble Towels', 'Tovla', 'MIWEVRO', 'FORLIM', 'DASH', 'Pipishell',
#        'Utopia Kitchen', 'Hibbent', 'RISICULIS', 'Umite Chef', 'OXO',
#        'SONGMICS', 'HuggieGems', 'Riveira', 'C CREST', 'Rubbermaid',
#        'Peach Street', 'BELLA', 'fullstar', 'TUYU', 'Corelle',
#        'SinkShroom', 'BESTZMWK', 'Antonki', 'Grtard', 'BYkooc',
#        'Momo & Nashi', 'KitchenAid', 'VaeFae', 'RAIQEE', 'Farberware',
#        'MUTNITT', 'HOTEC', 'Goodluck', 'longzon', 'KITESSENSU',
#        'BUNDLEPRO', 'TiKenSo', 'MontNorth', 'Swedish Wholesale', 'AIRNEX',
#        'Delamu', 'Wettex', 'Dutewo', 'iBayam', 'ACTIVE', 'Vtopmart',
#        'MAIPOR', 'Ultrean', 'Crock-Pot', 'ZULAY KITCHEN', 'REALINN',
#        'Lysol', 'HOOJO', 'NutriChef', 'Hamilton Beach', 'Oxepleus',
#        'UNERVER', 'SENSARTE', 'ALLTOP', 'Priority Chef', 'COSYLAND',
#        'KEGOUU', 'EXCELSTEEL', 'YLYL', 'KIZEN', 'iDesign', 'Snuuoby',
#        'BFONS', 'CADAVO', 'George Foreman', 'KEMETHY', 'Gorilla Grip',
#        'LANDNEOO', 'WOODENHOUSE LIFELONG QUALITY', 'YouCopia', 'SURDOCA',
#        'LOVIMAG', 'HLOOL', 'BIDFUL', 'Zyliss', "Luigi's", 'OBODING',
#        'Pomeat', 'Gamtik', 'Fader', 'DEKAVA', 'COKSDUPID', 'Ganiza',
#        'WHYSKO', 'canslab', 'Play-Doh', 'ROYAL CRAFT WOOD', 'Empune',
#        'Magic Bullet', 'NiuYichee', "Chef's Path", 'G-TING', 'niffgaff',
#        'Granitestone', 'SUNWUKIN', 'YIHONG', 'AOTHOD', 'BRIOUT',
#        'SunnyPoint', 'SIMPLI-MAGIC', 'PH PERKHOMY', 'Viretang', 'Syntus',
#        'Jo Chef', 'KeyFar', 'Copco', 'TMEDW', 'HOMEXCEL', 'Nicewell',
#        'Mattitude', 'Black+Decker', 'SpaceAid', 'BOYAN', 'Blue Diamond',
#        'Greater Goods', 'Homaxy', 'Totally Bamboo', 'Cambom', 'COKUNST',
#        'TrendPlain', 'Folksy Super Kitchen', 'PANTRYSTAR'], dtype=object)

# %%
#  drops rows with missing values
data.dropna()
# Out:
#                                                  title          brand  \
# 0    Amazon Basics Digital Kitchen Scale with LCD D...  Amazon Basics
# 2    Hefty Ultra Strong Tall Kitchen Trash Bags, La...          Hefty
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...  Amazon Basics
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...       Etekcity
# 7    Hefty Ultra Strong Tall Kitchen Trash Bags, Fa...          Hefty
# ..                                                 ...            ...
# 246  BLACK+DECKER EM720CB7 Digital Microwave Oven w...   Black+Decker
# 249  Pot and Pan Protectors, Set of 12 and 3 Differ...          BOYAN
# 250  Cookware Diamond Infused Ceramic Nonstick 8" F...   Blue Diamond
# 254  YouCopia StoraLid Food Container Lid Organizer...       YouCopia
# 257  Amazon Basics Flextra Tall Kitchen Drawstring ...  Amazon Basics
#
#                                            description  stars  reviewsCount  \
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 2    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.8         67700
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# 7    Trust Hefty Ultra Strong Tall Kitchen Trash Ba...    4.7          7450
# ..                                                 ...    ...           ...
# 246  This professional-style Black + Decker 0.7 Cub...    4.4         27656
# 249  Pot and Pan Separators, Set of 12 and 3 Differ...    4.8         11363
# 250  A kitchen icon that delivers effortless nonsti...    4.4         38920
# 254  Cleans up cluttered container lids for an easy...    4.6         37575
# 257  Product DescriptionAmazon Basics Flextra Tall ...    4.5         15590
#
#     price/currency  price/value  \
# 0                $        12.59
# 2                $        10.18
# 3                $        13.94
# 4                $        13.99
# 7                $        15.72
# ..             ...          ...
# 246              $        89.99
# 249              $        14.28
# 250              $        13.47
# 254              $        15.99
# 257              $        12.72
#
#                                            breadCrumbs        asin  \
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 2    Health & Household › Household Supplies › Pape...  B01BZ0LXL8
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# 7    Health & Household › Household Supplies › Pape...  B097F7XJM1
# ..                                                 ...         ...
# 246  Home & Kitchen › Kitchen & Dining › Small Appl...  B07HGH1KG6
# 249  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B07JJPYSRD
# 250  Home & Kitchen › Kitchen & Dining › Cookware ›...  B08223PQFX
# 254  Home & Kitchen › Kitchen & Dining › Storage & ...  B07FNRXFTD
# 257  Health & Household › Household Supplies › Pape...  B092VQMW7T
#
#                                       url
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 2    https://www.amazon.com/dp/B01BZ0LXL8
# 3    https://www.amazon.com/dp/B093X8QQ12
# 4    https://www.amazon.com/dp/B0113UZJE2
# 7    https://www.amazon.com/dp/B097F7XJM1
# ..                                    ...
# 246  https://www.amazon.com/dp/B07HGH1KG6
# 249  https://www.amazon.com/dp/B07JJPYSRD
# 250  https://www.amazon.com/dp/B08223PQFX
# 254  https://www.amazon.com/dp/B07FNRXFTD
# 257  https://www.amazon.com/dp/B092VQMW7T
#
# [80 rows x 10 columns]

# %%
# Print the shape of the dataset
data.shape
# Out:
# (262, 10)

# %%
# check the rows if any cell is null value then replace with True
data.dropna(inplace=True)

# %%
#  used to identify duplicated values in specified column
data['description'].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 257    False
# 258     True
# 259     True
# 260     True
# 261     True
# Name: description, Length: 262, dtype: bool

# %%
# used to identify duplicated values and replace by True
data.drop_duplicates(inplace=True)

# %%
# Display the number of duplicate rows found in the DataFrame.
duplicate_rows = data.duplicated() 
print(duplicate_rows.sum())
# Out:
# 0

# %% [markdown]
# ##  Step 5 : Data Sorting / Searching / Validation

# %%
# Display the reviwes count in shuffeled order
data['reviewsCount']
# Out:
# 0       86863
# 2       67700
# 3       80534
# 4      166658
# 7        7450
#         ...
# 246     27656
# 249     11363
# 250     38920
# 254     37575
# 257     15590
# Name: reviewsCount, Length: 80, dtype: int64

# %%
# arranging the values of reviewsCount in ascending order
data.sort_values('reviewsCount',ascending=True)
# Out:
#                                                  title          brand  \
# 210  Play-Doh Swirlin' Smoothies Toy Blender Playse...       Play-Doh
# 204  2 Pack Cup Slicers | Egg Slicers | banana slic...      COKSDUPID
# 214  magic bullet Portable Blender MBPB50100 Silver...   Magic Bullet
# 231  PerkHomy Cotton Butchers Twine String 500 Feet...    PH PERKHOMY
# 26   Pyrex 4-Cup Glass Measuring Cup For Baking and...          Pyrex
# ..                                                 ...            ...
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...  Amazon Basics
# 0    Amazon Basics Digital Kitchen Scale with LCD D...  Amazon Basics
# 68   Joseph Joseph DrawerStore Compact Utensil Orga...  Joseph Joseph
# 94   Rubbermaid 60-Piece Food Storage Containers wi...     Rubbermaid
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...       Etekcity
#
#                                            description  stars  reviewsCount  \
# 210  Whirl into imaginative play with the Play-Doh ...    4.5           262
# 204  2 Pack Cup Slicers | Egg Slicers | banana slic...    4.2           328
# 214  Great blends, no limits. That's the vibe with ...    4.1           719
# 231  【PERKHOMY'S NEW ARRIVAL】100% Cotton Butcher Tw...    4.8          1260
# 26   Generations of bakers and cooks have relied on...    4.7          1377
# ..                                                 ...    ...           ...
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 68   This revolutionary design is such a simple ide...    4.5         88613
# 94   Easily store food while minimizing clutter aro...    4.7        105153
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
#
#     price/currency  price/value  \
# 210              $         9.97
# 204              $         9.99
# 214              $        29.99
# 231              $         4.99
# 26               $         9.99
# ..             ...          ...
# 3                $        13.94
# 0                $        12.59
# 68               $         9.41
# 94               $        35.99
# 4                $        13.99
#
#                                            breadCrumbs        asin  \
# 210        Toys & Games › Arts & Crafts › Clay & Dough  B0C3528VHM
# 204  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0C4SWJWQF
# 214  Home & Kitchen › Kitchen & Dining › Small Appl...  B0CFSD8DHF
# 231  Tools & Home Improvement › Hardware › Tarps & ...  B0BXSBTNQN
# 26   Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0BSK2HF19
# ..                                                 ...         ...
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 68   Home & Kitchen › Kitchen & Dining › Storage & ...  B072R6CLRC
# 94   Home & Kitchen › Kitchen & Dining › Storage & ...  B07PTWH38V
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
#
#                                       url
# 210  https://www.amazon.com/dp/B0C3528VHM
# 204  https://www.amazon.com/dp/B0C4SWJWQF
# 214  https://www.amazon.com/dp/B0CFSD8DHF
# 231  https://www.amazon.com/dp/B0BXSBTNQN
# 26   https://www.amazon.com/dp/B0BSK2HF19
# ..                                    ...
# 3    https://www.amazon.com/dp/B093X8QQ12
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 68   https://www.amazon.com/dp/B072R6CLRC
# 94   https://www.amazon.com/dp/B07PTWH38V
# 4    https://www.amazon.com/dp/B0113UZJE2
#
# [80 rows x 10 columns]

# %%
# arranging the values of reviewsCount in descending order
data.sort_values('reviewsCount',ascending=False)
# Out:
#                                                  title          brand  \
# 4    Etekcity Food Scale, Digital Kitchen Scale, 30...       Etekcity
# 94   Rubbermaid 60-Piece Food Storage Containers wi...     Rubbermaid
# 68   Joseph Joseph DrawerStore Compact Utensil Orga...  Joseph Joseph
# 0    Amazon Basics Digital Kitchen Scale with LCD D...  Amazon Basics
# 3    Amazon Basics Tall Kitchen Drawstring Trash Ba...  Amazon Basics
# ..                                                 ...            ...
# 26   Pyrex 4-Cup Glass Measuring Cup For Baking and...          Pyrex
# 231  PerkHomy Cotton Butchers Twine String 500 Feet...    PH PERKHOMY
# 214  magic bullet Portable Blender MBPB50100 Silver...   Magic Bullet
# 204  2 Pack Cup Slicers | Egg Slicers | banana slic...      COKSDUPID
# 210  Play-Doh Swirlin' Smoothies Toy Blender Playse...       Play-Doh
#
#                                            description  stars  reviewsCount  \
# 4    This Etekcity digital scale has endless uses f...    4.6        166658
# 94   Easily store food while minimizing clutter aro...    4.7        105153
# 68   This revolutionary design is such a simple ide...    4.5         88613
# 0    Product DescriptionAn Amazon Brand.From the Ma...    4.7         86863
# 3    Product DescriptionAmazon Basics Tall Kitchen ...    4.7         80534
# ..                                                 ...    ...           ...
# 26   Generations of bakers and cooks have relied on...    4.7          1377
# 231  【PERKHOMY'S NEW ARRIVAL】100% Cotton Butcher Tw...    4.8          1260
# 214  Great blends, no limits. That's the vibe with ...    4.1           719
# 204  2 Pack Cup Slicers | Egg Slicers | banana slic...    4.2           328
# 210  Whirl into imaginative play with the Play-Doh ...    4.5           262
#
#     price/currency  price/value  \
# 4                $        13.99
# 94               $        35.99
# 68               $         9.41
# 0                $        12.59
# 3                $        13.94
# ..             ...          ...
# 26               $         9.99
# 231              $         4.99
# 214              $        29.99
# 204              $         9.99
# 210              $         9.97
#
#                                            breadCrumbs        asin  \
# 4    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0113UZJE2
# 94   Home & Kitchen › Kitchen & Dining › Storage & ...  B07PTWH38V
# 68   Home & Kitchen › Kitchen & Dining › Storage & ...  B072R6CLRC
# 0    Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B06X9NQ8GX
# 3    Health & Household › Household Supplies › Pape...  B093X8QQ12
# ..                                                 ...         ...
# 26   Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0BSK2HF19
# 231  Tools & Home Improvement › Hardware › Tarps & ...  B0BXSBTNQN
# 214  Home & Kitchen › Kitchen & Dining › Small Appl...  B0CFSD8DHF
# 204  Home & Kitchen › Kitchen & Dining › Kitchen Ut...  B0C4SWJWQF
# 210        Toys & Games › Arts & Crafts › Clay & Dough  B0C3528VHM
#
#                                       url
# 4    https://www.amazon.com/dp/B0113UZJE2
# 94   https://www.amazon.com/dp/B07PTWH38V
# 68   https://www.amazon.com/dp/B072R6CLRC
# 0    https://www.amazon.com/dp/B06X9NQ8GX
# 3    https://www.amazon.com/dp/B093X8QQ12
# ..                                    ...
# 26   https://www.amazon.com/dp/B0BSK2HF19
# 231  https://www.amazon.com/dp/B0BXSBTNQN
# 214  https://www.amazon.com/dp/B0CFSD8DHF
# 204  https://www.amazon.com/dp/B0C4SWJWQF
# 210  https://www.amazon.com/dp/B0C3528VHM
#
# [80 rows x 10 columns]

# %%
# to filter the price/value data which is greater than 50
df = data[data['price/value'] > 50]['price/value']
print(df)
# Out:
# 12      71.19
# 27     149.99
# 38      79.99
# 62     129.99
# 99      54.99
# 101    159.99
# 102     52.78
# 123     59.98
# 126     89.95
# 165     99.95
# 168     59.99
# 220    126.99
# 246     89.99
# Name: price/value, dtype: float64

# %% [markdown]
# ## Step 6 : Data Visualization

# %%
# to creates a DataFrame containing the first 20 rows of the original data.
df = pd.DataFrame(data.head(10))

# calculates the frequency of each unique value in the 'stars' column of the DataFrame and display the percentage of each slice.
df['asin'].value_counts().plot(kind='pie',autopct='%1.1f%%')

# to give the title of the plot
plt.title('Frequency of ASINs')

# to display the pie chart
plt.show()

# %%
# to creates a DataFrame containing the first 20 rows of the original data.
df = pd.DataFrame(data.head(15))

# calculates the frequency of each unique value in the 'stars' column of the DataFrame and display the percentage of each slice.
df['brand'].value_counts().plot(kind='bar', color='Blue')

# Set the label for the x-axis
plt.xlabel('brand')

# Set the label for the y-axis
plt.ylabel('price/value')

# to give the title of the plot
plt.title('Frequency of Brands')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=60)

# to display the pie chart
plt.show()

# %%
# to creates a DataFrame containing the first 20 rows of the original data.
df = pd.DataFrame(data.head(15))

# calculates the frequency of each unique value in the 'stars' column of the DataFrame and display the percentage of each slice.
df['stars'].value_counts().plot(kind='line', color='Brown')

# Set the label for the x-axis
plt.xlabel('stars')

# Set the label for the y-axis
plt.ylabel('price/value')

# to give the title of the plot
plt.title('Frequency of Stars')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0)

# to display the pie chart
plt.show()

# %%
# to creates a DataFrame containing the first 20 rows of the original data.
df = pd.DataFrame(data.head(15))

# calculates the frequency of each unique value in the 'stars' column of the DataFrame and display the percentage of each slice.
df['stars'].value_counts().plot(kind='hist', color='Yellow')

# Set the label for the x-axis
plt.xlabel('stars')

# Set the label for the y-axis
plt.ylabel('price/value')

# to give the title of the plot
plt.title('Frequency of Stars')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0)

# to display the pie chart
plt.show()

# %%
# to creates a DataFrame containing the first 20 rows of the original data.
df = pd.DataFrame(data.head(15))

# calculates the frequency of each unique value in the 'stars' column of the DataFrame and display the percentage of each slice.
df['stars'].value_counts().plot(kind='barh', color='Red')

# Set the label for the x-axis
plt.xlabel('stars')

# Set the label for the y-axis
plt.ylabel('price/value')

# to give the title of the plot
plt.title('Frequency of Stars')

# Rotate the x-axis labels for better readability
plt.xticks(rotation=0)

# to display the pie chart
plt.show()

# %%
# Create a DataFrame containing the first 15 rows of the original data
df = pd.DataFrame(data.head(15))

# Calculate the frequency of each unique value in the 'stars' column
stars_freq = df['stars'].value_counts()

# Create x and y values for the scatter plot
x_values = stars_freq.index
y_values = stars_freq.values

# Plot the scatter plot
plt.scatter(x_values, y_values, color='Black')

# Set the label for the x-axis
plt.xlabel('Stars')

# Set the label for the y-axis
plt.ylabel('price/value')

# Set the title of the plot
plt.title('Frequency of Stars')

# Display the plot
plt.show()
